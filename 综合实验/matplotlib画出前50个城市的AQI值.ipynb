# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.rcParams['font.sans-serif'] = ['Microsoft YaHei'] # 解决中文不能正常显示的问题
plt.rcParams['axes.unicode_minus'] = False  # 不显示负值

# %%
def main():
    """
        主函数
    """
    aqi_data = pd.read_csv('data/china_city_AQI.csv')
    print('基本信息：')
    print(aqi_data.info())

    print('数据预览：')
    print(aqi_data.head())

    # 数据清洗
    clean_aqi_data = aqi_data[aqi_data['AQI'] > 0]

    # 基本统计
    print('AQI最大值:', clean_aqi_data['AQI'].max())
    print('AQI最小值：', clean_aqi_data['AQI'].min())
    print('AQI均值：', clean_aqi_data['AQI'].mean())

    # top50
    top50_cities = clean_aqi_data.sort_values(by=['AQI']).head(50)
    print(top50_cities)
    top50_cities.plot(kind='bar', x='City', y='AQI', title='空气质量最好的50个城市',
                      figsize=(20, 10))
    plt.savefig('data/top50_aqi_bar.png')
    plt.show()

# %%
main()
# Out:
# 基本信息：
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 375 entries, 0 to 374
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   City      375 non-null    object
#  1   AQI       375 non-null    int64
#  2   PM2.5/1h  375 non-null    int64
#  3   PM10/h    375 non-null    int64
#  4   CO/1h     375 non-null    float64
#  5   NO2/1h    375 non-null    int64
#  6   O3/1h     375 non-null    int64
#  7   O3/8h     375 non-null    int64
#  8   SO2/1h    375 non-null    int64
# dtypes: float64(1), int64(7), object(1)
# memory usage: 26.5+ KB
# None
# 数据预览：
#     City  AQI  PM2.5/1h  PM10/h  CO/1h  NO2/1h  O3/1h  O3/8h  SO2/1h
# 0    阿坝州   34        11      24   0.90      19     64     67       7
# 1  阿克苏地区  171        82     290   0.90      35     48     28      14
# 2   阿拉善盟  113        84     106   0.87      27     74     71      19
# 3  阿勒泰地区   25         5      14   1.15       7     40     48      18
# 4   阿里地区    0         0       0   0.00       0      0     64       0
# AQI最大值: 500
# AQI最小值： 18
# AQI均值： 91.53494623655914
#       City  AQI  PM2.5/1h  PM10/h  CO/1h  NO2/1h  O3/1h  O3/8h  SO2/1h
# 358     肇庆   18        11      17   0.65      22     18     26       5
# 177   林芝地区   18         4      16   0.35       6     51     35       3
# 223     清远   19        13      18   0.90      19     16     23       4
# 318  西双版纳州   19         8      14   0.60      12     38     36       7
# 200     南平   20        13      19   0.75      16     26     27       6
# 338     鹰潭   23        16      19   0.48      23     11     13       6
# 248     韶关   23        15      22   0.88      22     19     23       8
# 115    黄南州   24         9      23   1.10      35     43     47      24
# 81      广州   25        17      24   0.86      36      7     15       3
# 3    阿勒泰地区   25         5      14   1.15       7     40     48      18
# 206     宁德   25        15      24   0.57      13     45     39       4
# 216     莆田   26        10      22   0.72      21     49     51       5
# 47     楚雄州   26         7      19   0.70       7     48     51       8
# 237     三明   26        18      24   0.73      19      9     12       7
# 106     河源   26        16      25   0.83      24     25     32       6
# 155     昆明   27        11      25   0.79      21     52     53       9
# 310  锡林郭勒盟   27         7      24   0.30      28     35     52      17
# 349     玉溪   27         9      19   0.73      12     69     53       6
# 228     泉州   28        11      27   0.43      17     47     54       6
# 215     普洱   28        10      14   0.65      11     56     55       2
# 99      河池   29        20      27   0.60      10     58     54       7
# 232  日喀则地区   29         6      27   0.35       2     68     56       5
# 289    文山州   29        17      28   0.75      17     27     24       5
# 32    昌都地区   29         6      12   0.70      11     86     57       8
# 183     龙岩   29        16      28   0.65      20     35     43       9
# 238     三沙   30         7      20   0.30      30     51     58       6
# 108     贺州   30        21      28   0.65       8     37     37      11
# 89    海东地区   30        15      23   0.80      19     64     58      11
# 203   那曲地区   30        13      13   0.90       7     66     58       4
# 333     伊春   31        16      27   0.30       8     61     61       4
# 339     义乌   32         0       0   1.40      63     10     18       0
# 180     柳州   32        15      31   0.88      12     47     48       5
# 78     甘孜州   32        11      23   0.50      25     62     62       4
# 302     厦门   32        13      24   0.57      22     86     62       3
# 148     鸡西   32        18      31   0.43      28     43     51       9
# 68      佛山   33        21      32   0.91      39      6     13       5
# 138    景德镇   33        20      32   0.70      16     17     20       5
# 82      贵港   34        23      33   0.75      15     56     52       7
# 348    玉树州   34         0       8   0.40       7     76     67       4
# 239     三亚   34        12      19   0.85      12     68     66       3
# 231    日喀则   34         7      14   0.65      10     70     66       9
# 0      阿坝州   34        11      24   0.90      19     64     67       7
# 209    攀枝花   35        20      34   0.60      35     67     54      23
# 165    凉山州   35        19      33   0.74      21     76     68      13
# 92     海南州   35         8      15   0.60       8     73     69      11
# 16      保山   36         9      27   0.40      12     79     71       5
# 176     林芝   37         8      27   0.25       4     83     72       3
# 172     临沧   37        20      36   0.60       6     66     57      10
# 244     山南   37         7      21   0.45       8     76     73       2
# 230     衢州   38        26      32   0.80      45     20     23       5
