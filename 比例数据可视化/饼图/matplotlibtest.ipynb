# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
plt.rcParams['font.family']=['sans-serif']
plt.rcParams['font.sans-serif']=['SimHei']

# %%
plt.figure(figsize=(9,9))
plt.title('感兴趣的数据领域')
t='数据可视化-用户感兴趣领域，以下是读者的投票结果。 \n读者对金融、医疗保健、时长3个领域最感兴趣。'
plt.text(-1.3,1.3,t,fontsize=8,va='top',ha='left')
data = pd.read_csv('../data/vote_result.csv')
plt.pie(data['Votes'],labels=data['Areas_of_interest'],autopct='%1.1%%',startangle=90,counterclock=False)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 6
#       4 plt.text(-1.3,1.3,t,fontsize=8,va='top',ha='left')
#       5 data = pd.read_csv('../data/vote_result.csv')
# ----> 6 plt.pie(data['Votes'],labels=data['Areas_of_interest'],autopct='%1.1%%',startangle=90,counterclock=False)
#       7 plt.show()
#
# File E:\Python\python3.12.0\Lib\site-packages\matplotlib\pyplot.py:3546, in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, hatch, data)
#    3523 @_copy_docstring_and_deprecators(Axes.pie)
#    3524 def pie(
#    3525     x: ArrayLike,
#    (...)
#    3544     data=None,
#    3545 ) -> tuple[list[Wedge], list[Text]] | tuple[list[Wedge], list[Text], list[Text]]:
# -> 3546     return gca().pie(
#    3547         x,
# ...
