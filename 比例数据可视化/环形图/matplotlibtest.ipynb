# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.rcParams['font.family']=['sans-serif']
plt.rcParams['font.sans-serif']=['SimHei']

# %%
plt.figure(figsize=(9,9))
plt.title('感兴趣的数据领域')
t='数据可视化 数据可视化--用户感兴趣领域 用户感兴趣领域,,以下是读者的投票结果。 以下是读者的投票结果。\n读者对金融、医疗保健、市场业3个领域最感兴趣。'
plt.text(-1.3,1.3,t,fontsize=8,va='top',ha='left')
data = pd.read_csv('../data/vote_result.csv')
plt.pie(data['Votes'],labels=data['Areas_of_interest'],autopct='%1.1f%%',startangle=90,counterclock=False)
tmp=[1]
plt.pie(tmp,labels=[' '],radius=0.5,colors='w')
plt.show()
